# %%
###Task 1
from PIL import Image

img=Image.open("C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg")
width,hieght=img.size
img_lst=img.load()
hieght,width

for i in range (width):
  for j in range(hieght):
    img_lst[i,j]=(img_lst[i,j][0]+150,img_lst[i,j][1]+150,img_lst[i,j][2]+150)

img.show()

# %%
import cv2
import matplotlib.pyplot as plt

img1=cv2.imread("C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg",1)
#img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
#plt.imshow(img1)
cv2.imshow("new image",img1)
k=cv2.waitKey(0)
#K=cv2.waitKey(5000)
#cv2.destroyAllWindows() # waits 5 s and then close the image window


if k==27:
  cv2.destroyAllWindows() 
elif k== ord("s"):
  cv2.imwrite("sec image..jpg",img1)
  cv2.destroyAllWindows()

# %%
# Task 2 read from video 
video_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\Data_Videos\\ForTal\\British_Football_Hooligans_Mix_3__MorningGlory1997__kW23lUV6oFk.avi"

video=cv2.VideoCapture(video_path)
video.read()[1].size

# %%
# Task 3  read from web cam
import cv2
import matplotlib.pyplot as plt
cap=cv2.VideoCapture(0)
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('output.avi',fourcc,20,(640,480))
print(cap.isOpened())
while(cap.isOpened()):
  return1,frame=cap.read()
  if return1:
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 480)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)

    out.write(frame)
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("frame",gray)
    if cv2.waitKey(1)==ord("q"):
      break
  else:
    break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
#3rd task 
import numpy as np 
import cv2

img =np.zeros([512,512,3],np.uint8)

#img=cv2.line(img,(0,0),(255,255),(0,0,255),10)
#img=cv2.arrowedLine(img,(0,255),(255,255),(0,0,255),10)
#img=cv2.rectangle(img,(255,255),(300,300),(0,0,255),10)
#img=cv2.rectangle(img,(255,255),(300,300),(0,0,255),-1) #fill solid rectangle
#img=cv2.circle(img,(255,255),10,(0,255,0),1)

#font=cv2.FONT_HERSHEY_SIMPLEX
#img=cv2.putText(img,"ML & AI Engineer",(10,100),font,4,(0,255,0),10)

pts=np.array([[10,5],[20,30],[70,20],[50,20]],np.int32)
img=cv2.polylines(img,[pts],True,(0,255,255))


cv2.imshow("img1",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
 img.size
# Out:
# 786432

# %%
#Task of setting paramter of your camera 

import cv2
import matplotlib.pyplot as plt
cap=cv2.VideoCapture(0)
print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

cap.set(3,4000)
cap.set(4,2000)

print(cap.get(3))
print(cap.get(4))

print(cap.isOpened())
while(cap.isOpened()):
  return1,frame=cap.read()
  if return1:
   
   
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("frame",gray)
    
    if cv2.waitKey(1)==ord("q"):
      break
  else:
    break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0
# 640.0
# 480.0
# True

# %%
# Task 5
import cv2
import datetime
cap = cv2.VideoCapture(0)
#print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.set(3, 3000)
cap.set(4, 3000)
print(cap.get(3))
print(cap.get(4))
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:

       font = cv2.FONT_HERSHEY_SIMPLEX
       text = 'Width: '+ str(cap.get(3)) + ' Height:' + str(cap.get(4))
       datet = str(datetime.datetime.now())
       frame = cv2.putText(frame, text, (10, 50), font, 1,
                           (0, 255, 255), 2)
       frame = cv2.putText(frame, datet, (10, 100), font, 1,
                           (0, 255, 255), 2)
       cv2.imshow('frame', frame)

       if cv2.waitKey(1)== ord('q'):
         break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0

# %%
#6th Task
import numpy as np
import cv2

events = [i for i in dir(cv2) if 'EVENT' in  i]
print(events)

def click_event(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,', ' ,y)
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + ', '+ str(y)
        cv2.putText(img, strXY, (x, y), font, .5, (255, 255, 0), 2)
        cv2.imshow('image', img)
    if event == cv2.EVENT_RBUTTONDOWN:
        blue = img[y, x, 0]
        green = img[y, x, 1]
        red = img[y, x, 2]
        font = cv2.FONT_HERSHEY_SIMPLEX
        strBGR = str(blue) + ', '+ str(green)+ ', '+ str(red)
        cv2.putText(img, strBGR, (x, y), font, .5, (0, 255, 255), 2)
        cv2.imshow('image', img)

#img = np.zeros((512, 512, 3), np.uint8)
img_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg"
img = cv2.imread(img_path)
cv2.imshow('image', img)

cv2.setMouseCallback('image', click_event)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']
# 477 ,  155
# 29 ,  38
# 67 ,  84
# 103 ,  149
# 77 ,  196
# 82 ,  278
# 404 ,  293
# 396 ,  289
# 394 ,  323
# 393 ,  359
# 430 ,  391
# 423 ,  452
# 393 ,  211
# 392 ,  244
# 361 ,  253
# 332 ,  267
# 320 ,  283
# 306 ,  321
# 332 ,  350
# 343 ,  358
# 309 ,  160
# 491 ,  320
# 174 ,  236
# 174 ,  159
# 227 ,  118
# 285 ,  92
# 312 ,  195
# 203 ,  267
# 208 ,  285
# 274 ,  310
# 189 ,  570

# %%
import cv2
img1_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg"
img2_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\sample_image.jpg"

img1=cv2.imread(img1_path)
img2=cv2.imread(img2_path)

print(img1.shape)
print(img1.size)
print(img1.dtype)

b,g,r=cv2.split(img1)
image=cv2.merge((b,g,r))
###########################################################33
## splitting part of picture and add it in another place

# import matplotlib.pyplot as plt
# plt.imshow(img2)
# ratio=4555/2505
# width=int(ratio*600)
# img_resize=cv2.resize(img2,(width,600))

# Robot=img_resize[200:600,0:400]
# img_resize[200:600,400:800]=Robot

# #plt.imshow(img_resize)
####################################################################
## add two image in one image
img1=cv2.resize(img1,(520,520))
img2=cv2.resize(img2,(520,520))
img_merged=cv2.add(img1,img2)
#plt.imshow(img_merged)

#######################################################
img_merged=cv2.addWeighted(img1,.9,img2,.8,0)# last element play on the brightness of the image
plt.imshow(img_merged)
# Out:
# (602, 900, 3)
# 1625400
# uint8

# %%
import numpy as np 
import cv2
def nothing(x):
  print(x)

img=np.zeros((300,512,3),np.uint8)
cv2.namedWindow("image")

cv2.createTrackbar('B','image',0,255,nothing)
cv2.createTrackbar('G','image',0,255,nothing)
cv2.createTrackbar('R','image',0,255,nothing)

switch='0 : OFF \n 1:ON'
cv2.createTrackbar(switch,'image',0,1,nothing)

while (True):
  cv2.imshow("image",img)
  if cv2.waitKey(1)==ord("q"):
    break
  
  b=cv2.getTrackbarPos('B','image')
  g=cv2.getTrackbarPos('G','image')
  r=cv2.getTrackbarPos('R','image')
  s=cv2.getTrackbarPos(switch,'image')
  
  if s==0:
    img[:]=0
  else:
    img[:]=[b,g,r]

cv2.destroyAllWindows()
# Out:
# 51
# 51
# 0
# 51
# 0
# 52
# 53
# 56
# 59
# 64
# 68
# 70
# 72
# 74
# 75
# 76
# 77
# 73
# 65
# 51
# 33
# 17
# 4
# 0

# %% [markdown]
# #Object Detection using HSV Semantic Segmentation

# %%
#Object Detection using HSV
import cv2 
import matplotlib.pyplot as plt
from matplotlib import colors
img1_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg"
nemo=cv2.imread(img1_path)
hsv_nemo = cv2.cvtColor(nemo, cv2.COLOR_RGB2HSV)
h, s, v = cv2.split(hsv_nemo)
fig = plt.figure()

axis = fig.add_subplot(1, 1, 1, projection="3d")
pixel_colors = nemo.reshape((np.shape(nemo)[0]*np.shape(nemo)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Hue")
axis.set_ylabel("Saturation")
axis.set_zlabel("Value")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

while (True):
  img1_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg"
  nemo1=cv2.imread(img1_path)
 
  nemo=cv2.cvtColor(nemo1,cv2.COLOR_BGR2RGB)
  hsv_nemo = cv2.cvtColor(nemo, cv2.COLOR_RGB2HSV)
  light_orange=(1,190,200)
  dark_orange=(18,255,255)
  mask1=cv2.inRange(hsv_nemo,light_orange,dark_orange)
  result=cv2.bitwise_and(nemo,nemo,mask=mask1)

  cv2.imshow("result",result)
  cv2.imshow("mask",mask1)
  cv2.imshow("Original",nemo1)

  if cv2.waitKey(1)==ord("q"):
    break
  
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np 
cap = cv2.VideoCapture(0)

while(cap.isOpened()):

    # Take each frame
    _, frame = cap.read()

    # Convert BGR to HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # define range of blue color in HSV
    lower_blue = np.array([0, 10, 60], dtype = "uint8")
    upper_blue = np.array([20, 150, 255], dtype = "uint8")

    # Threshold the HSV image to get only blue colors
    mask = cv2.inRange(hsv, lower_blue, upper_blue)

    # Bitwise-AND mask and original image
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    k = cv2.waitKey(5) & 0xFF
    if k == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #**Smoothing and Blooring Image**

# %%
import cv2
import matplotlib.pyplot as plt

img1_path="C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\data\\nemo_1.jpg"
nemo1=cv2.imread(img1_path)
nemo1=cv2.cvtColor(nemo1,cv2.COLOR_BGR2RGB)

#Blurization
#averageing=cv2.blur(nemo1,(5,5)) ## mean for pixels
#averageing=cv2.GaussianBlur(nemo1,(5,5),1) ##for noise images  
#averageing=cv2.medianBlur(nemo1,5) ## for salt ans paper images
averageing=cv2.bilateralFilter(nemo1,9,75,75) ##smoothing and concenterate with edges
plt.imshow(averageing)

# %%
import cv2

cap=cv2.VideoCapture(0)

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 480)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)
print(cap.isOpened())
face_cascade=cv2.CascadeClassifier("C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\haarcascade_frontalface_default.xml")
eye_cascade=cv2.CascadeClassifier("C:\\Users\\Abdelrahman Ahmed\\Downloads\\coding\\Computer Vision\\haarcascade_eye.xml")
while (cap.isOpened()):
  _,frame=cap.read()

  gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
  faces=face_cascade.detectMultiScale(gray,1.1,4)
  
  for (x,y,w,h) in faces:
    cv2.rectangle(frame,(x,y),(x+w,y+h),(0,250,0),4)
    cv2.putText(frame,"face",(x,y-4),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),3)
    eyes=eye_cascade.detectMultiScale(gray,2.3,4)
    for (ex,ey,ew,eh) in eyes:
      cv2.rectangle(frame,(ex,ey),(ex+ew,ey+eh),(0,0,250),4)
      cv2.putText(frame,"eyes",(ex,ey-4),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),3)


  cv2.imshow("img",frame)
  if cv2.waitKey(1)==ord("q"):
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# True

# %% [markdown]
# #Object Detetction Using Yolo and CV2

# %%
import cv2
import argparse
import numpy as np



def get_output_layers(net):
    
    layer_names = net.getLayerNames()
    
    output_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers()]

    return output_layers


def draw_prediction(img, class_id, confidence, x, y, x_plus_w, y_plus_h):

    label = str(classes[class_id])

    color = COLORS[class_id]

    cv2.rectangle(img, (x,y), (x_plus_w,y_plus_h), color, 2)

    cv2.putText(img, label, (x-10,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

###############################################################################################################
classes = None
with open("C:\\Users\\Abdelrahman Ahmed\\Downloads\\New folder (4)\\coco.names.txt","r") as f:
  classes=f.read().rstrip("\n").split("\n")


COLORS = np.random.uniform(0, 255, size=(len(classes), 3))

##############################################################################################################################
model="C:\\Users\\Abdelrahman Ahmed\\Downloads\\New folder (4)\\yolov3.weights"
config="C:\\Users\\Abdelrahman Ahmed\\Downloads\\New folder (4)\\yolov3.cfg"
net = cv2.dnn.readNet(model,config)

###################################################################################################################################

cap=cv2.VideoCapture(0)
print(cap.isOpened())

while (cap.isOpened()):
  _,image=cap.read()
  Width = image.shape[1]
  Height = image.shape[0]
  scale = 0.00392

  blob = cv2.dnn.blobFromImage(image, scale, (416,416), (0,0,0), True, crop=False)

  net.setInput(blob)

  outs = net.forward(get_output_layers(net))

  class_ids = []
  confidences = []
  boxes = []
  
  conf_threshold = 0.7
  nms_threshold = 0.5


  for out in outs:
    for detection in out:
      scores = detection[5:]
      class_id = np.argmax(scores)
      confidence = scores[class_id]
      if confidence > 0.5:
        center_x = int(detection[0] * Width)
        center_y = int(detection[1] * Height)
        w = int(detection[2] * Width)
        h = int(detection[3] * Height)
        x = center_x - w / 2
        y = center_y - h / 2
        class_ids.append(class_id)
        confidences.append(float(confidence))
        boxes.append([x, y, w, h])


  indices = cv2.dnn.NMSBoxes(boxes, confidences, conf_threshold, nms_threshold)

  for i in indices:
      
      box = boxes[i]
      x = box[0]
      y = box[1]
      w = box[2]
      h = box[3]
      draw_prediction(image, class_ids[i], confidences[i], round(x), round(y), round(x+w), round(y+h))

  cv2.imshow("image", image)
  if cv2.waitKey(1)==ord("q"):
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
image=cv2.imread("C:\\Users\\Abdelrahman Ahmed\\Downloads\\audience-citizen_0.jpg")
Width = image.shape[1]
Height = image.shape[0]
scale = 0.00392

blob = cv2.dnn.blobFromImage(image, scale, (416,416), (0,0,0), True, crop=False)

net.setInput(blob)
layer_names = net.getLayerNames()
output_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers()]

outs = net.forward(get_output_layers(net))

for out in outs:
  for detection in out:
    scores = detection[5:]
    class_id = np.argmax(scores)
    confidence = scores[class_id]
    if confidence > 0.5:
      center_x = int(detection[0] * Width)
      center_y = int(detection[1] * Height)
      w = int(detection[2] * Width)
      h = int(detection[3] * Height)
      x = center_x - w / 2
      y = center_y - h / 2
      class_ids.append(class_id)
      confidences.append(float(confidence))
      boxes.append([x, y, w, h])
    
indices_best_boxes = cv2.dnn.NMSBoxes(boxes, confidences, conf_threshold, nms_threshold)
 for i in indices_best_boxes:
      box = boxes[i]
      x = box[0]
      y = box[1]
      w = box[2]
      h = box[3]
      draw_prediction(image, class_ids[i], confidences[i], round(x), round(y), round(x+w), round(y+h))

  cv2.imshow("image", image)
